# %% [markdown]
# <a href="https://colab.research.google.com/github/AmanpreetKaur-123/TR-103-batch-2022-2026-/blob/main/Mini_Project(14_7_2025).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome! to Currency coverter project.....")
print("Hope your are doing well...")
exchange_rates = {
    "USD": 1.0,
    "INR": 83.0,
    "EUR": 0.92,
    "GBP": 0.78,
    "JPY": 156.9,
    "AUD": 1.50,
    "CAD": 1.36,
    "CNY": 7.25,
    "SAR": 3.75,
    "AED": 3.67
}

def show_currencies():
    print("\nAvailable currencies:")
    for currency in exchange_rates:
        print(f" - {currency}")

def convert_currency(amount, from_currency, to_currency):
    if from_currency not in exchange_rates or to_currency not in exchange_rates:
        print("Invalid currency code.")
        return None
    usd_amount = amount / exchange_rates[from_currency]
    converted = usd_amount * exchange_rates[to_currency]
    return converted

def main():
    print("OFFLINE CURRENCY CONVERTER")

    while True:
        show_currencies()

        from_currency = input("\nEnter source currency code: ").upper()
        to_currency = input("Enter target currency code: ").upper()

        try:
            amount = float(input(f"Enter amount in {from_currency}: "))
        except ValueError:
            print("Invalid amount. Please enter a number.")
            continue

        result = convert_currency(amount, from_currency, to_currency)

        if result is not None:
            print(f"\n{amount:.2f} {from_currency} = {result:.2f} {to_currency}")

        choice = input("\nDo you want to convert again? (y/n): ").lower()
        if choice != 'y':
            print("Thank you! Goodbye!")
            break

if __name__ == "__main__":
    main()
# Out:
# Welcome! to Currency coverter project.....
# Hope your are doing well...
# OFFLINE CURRENCY CONVERTER
#
# Available currencies:
#  - USD
#  - INR
#  - EUR
#  - GBP
#  - JPY
#  - AUD
#  - CAD
#  - CNY
#  - SAR
#  - AED
#
# Enter source currency code: INR
# Enter target currency code: EUR
# Enter amount in INR: 10
#
# 10.00 INR = 0.11 EUR
#
# Do you want to convert again? (y/n): N
# Thank you! Goodbye!
